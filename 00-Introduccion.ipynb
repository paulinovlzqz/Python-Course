# %% [markdown]
# # Python
#
# Voy a crear una serie de videos para que puedan aprender python de una forma sencilla, de igual forma en este canal podras encontrar tutoriales de python **completamente gratis** desde lo mas basico a conceptos avanzados.
#
# Python es usado para diferentes fines, como los siguientes:
#
# * Desarrollo web
# * Ciencia y Educacion
# * Desarrollo de Interfaces Graficas
# * Desarrollo de software
# * Machine learning
# * etc

# %% [markdown]
# Antes de empezar necesitamos tener instalado lo siguiente:
# 1. Python
# 2. visual studio code

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Para este curso me estare apoyando de NoteBooks ya que nos permiten crear codigo y texto narrativo para explicar lo que vayamos haciendo.
# Estos tienen la extension .ipynb mientras que los programas en python terminan con .py
#
# Nota: utilizar NoteBooks para proyectos grandes no es una alternativa.
